# %%
import cv2
import cvzone
import time
import math
import numpy as np

cap = cv2.VideoCapture(r"C:\Users\bathu\people_-_6387 (540p).mp4")
cap.set(3, 1280)  # Set width
cap.set(4, 720)   # Set height

model_path = "C:/Users/bathu/facial_recognition/yolov8l.pt"
model = YOLO(model_path)  
classNames = ['person']
heatmap = np.zeros((720, 1280), dtype=np.float32)

prev_frame_time = 0
new_frame_time = 0

while True:
    new_frame_time = time.time()
    success, img = cap.read()
    if not success:
        break

    results = model(img, stream=True)

    for r in results:
        boxes = r.boxes
        for box in boxes:
            if box.conf[0] < 0.2:
                continue

            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            heatmap[y1:y2, x1:x2] += 1
            cvzone.cornerRect(img, (x1, y1, x2 - x1, y2 - y1))
            conf = math.ceil((box.conf[0] * 100)) / 100
            cvzone.putTextRect(img, f'person {conf}', (max(0, x1), max(35, y1)), scale=1, thickness=2)

    fps = 1 / (new_frame_time - prev_frame_time)
    prev_frame_time = new_frame_time

    heatmap_normalized = np.uint8(255 * heatmap / np.max(heatmap))
    heatmap_color = cv2.applyColorMap(heatmap_normalized, cv2.COLORMAP_JET)

    overlayed_image = cv2.addWeighted(img, 0.8, heatmap_color, 0.2, 0)

    cv2.imshow('Overlayed Heatmap', overlayed_image)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
from ultralytics import YOLO
import math
import time

# %%
import cv2
import cvzone
import time
import math
import numpy as np

cap = cv2.VideoCapture(r"C:\Users\bathu\people_-_6387 (540p).mp4")
cap.set(3, 1280)  # Set width
cap.set(4, 720)   # Set height

model_path = "C:/Users/bathu/facial_recognition/yolov8l.pt"
model = YOLO(model_path)  
classNames = ['person']
heatmap = np.zeros((720, 1280), dtype=np.float32)

prev_frame_time = 0
new_frame_time = 0

while True:
    new_frame_time = time.time()
    success, img = cap.read()
    if not success:
        break

    results = model(img, stream=True)

    for r in results:
        boxes = r.boxes
        for box in boxes:
            if box.conf[0] < 0.2:
                continue

            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            heatmap[y1:y2, x1:x2] += 1
            cvzone.cornerRect(img, (x1, y1, x2 - x1, y2 - y1))
            conf = math.ceil((box.conf[0] * 100)) / 100
            cvzone.putTextRect(img, f'person {conf}', (max(0, x1), max(35, y1)), scale=1, thickness=2)

    fps = 1 / (new_frame_time - prev_frame_time)
    prev_frame_time = new_frame_time

    heatmap_normalized = np.uint8(255 * heatmap / np.max(heatmap))
    heatmap_color = cv2.applyColorMap(heatmap_normalized, cv2.COLORMAP_JET)

    heatmap_resized = cv2.resize(heatmap_color, (img.shape[1], img.shape[0]))

    overlayed_image = cv2.addWeighted(img, 0.8, heatmap_resized, 0.2, 0)

    cv2.imshow('Overlayed Heatmap', overlayed_image)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 25 persons, 1 handbag, 36.6ms
# Speed: 2.0ms preprocess, 36.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 33.3ms
# Speed: 2.6ms preprocess, 33.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 32.5ms
# Speed: 2.0ms preprocess, 32.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 34.1ms
# Speed: 2.1ms preprocess, 34.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 handbag, 33.7ms
# Speed: 2.0ms preprocess, 33.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 2 handbags, 33.5ms
# Speed: 1.0ms preprocess, 33.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 3 handbags, 32.1ms
# Speed: 2.1ms preprocess, 32.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
import cv2
import cvzone
import time
import math
import numpy as np

cap = cv2.VideoCapture(r"C:\Users\bathu\people_-_6387 (540p).mp4")

frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

model_path = "C:/Users/bathu/facial_recognition/yolov8l.pt"
model = YOLO(model_path)  
classNames = ['person']
heatmap = np.zeros((frame_height, frame_width), dtype=np.float32)

prev_frame_time = 0
new_frame_time = 0

while True:
    new_frame_time = time.time()
    success, img = cap.read()
    if not success:
        break

    results = model(img, stream=True)

    for r in results:
        boxes = r.boxes
        for box in boxes:
            if box.conf[0] < 0.2:
                continue

            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            heatmap[y1:y2, x1:x2] += 1 

    heatmap_normalized = np.uint8(255 * heatmap / np.max(heatmap))
    heatmap_color = cv2.applyColorMap(heatmap_normalized, cv2.COLORMAP_JET)

    img[heatmap_color > 0] = heatmap_color[heatmap_color > 0]

    cv2.imshow('Video with Heatmap', img)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 25 persons, 1 handbag, 32.5ms
# Speed: 2.0ms preprocess, 32.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 31.5ms
# Speed: 2.0ms preprocess, 31.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 29.7ms
# Speed: 2.6ms preprocess, 29.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 29.1ms
# Speed: 1.9ms preprocess, 29.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 handbag, 30.1ms
# Speed: 2.0ms preprocess, 30.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 2 handbags, 28.0ms
# Speed: 2.0ms preprocess, 28.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 3 handbags, 26.9ms
# Speed: 2.7ms preprocess, 26.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
import cv2
import cvzone
import time
import math
import numpy as np

cap = cv2.VideoCapture(r"C:\Users\bathu\people_-_6387 (540p).mp4")

frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

model_path = "C:/Users/bathu/facial_recognition/yolov8l.pt"
model = YOLO(model_path)  

classNames = ['person']
heatmap = np.zeros((frame_height, frame_width), dtype=np.float32)

while cap.isOpened():
    success, img = cap.read()
    if not success:
        break

    results = model(img, stream=True)

    for r in results:
        boxes = r.boxes
        for box in boxes:
            if box.conf[0] < 0.2:
                continue

            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            heatmap[y1:y2, x1:x2] += 1

heatmap_normalized = np.uint8(255 * heatmap / np.max(heatmap))
heatmap_color = cv2.applyColorMap(heatmap_normalized, cv2.COLORMAP_JET)

cv2.imshow('Cumulative Heatmap', heatmap_color)
cv2.waitKey(0)
cv2.destroyAllWindows()

cv2.imwrite('cumulative_heatmap.jpg', heatmap_color)

cap.release()
# Out:
# 0: 384x640 25 persons, 1 handbag, 32.9ms
# Speed: 2.0ms preprocess, 32.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 31.9ms
# Speed: 1.0ms preprocess, 31.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 33.1ms
# Speed: 2.2ms preprocess, 33.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 29.9ms
# Speed: 2.0ms preprocess, 29.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 handbag, 26.8ms
# Speed: 1.1ms preprocess, 26.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 2 handbags, 27.0ms
# Speed: 2.0ms preprocess, 27.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 3 handbags, 26.0ms
# Speed: 2.0ms preprocess, 26.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
import cv2
import cvzone
import time
import math
import numpy as np

cap = cv2.VideoCapture(r"C:\Users\bathu\people_-_6387 (540p).mp4")

frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

model_path = "C:/Users/bathu/facial_recognition/yolov8l.pt"
model = YOLO(model_path)  
classNames = ['person']
heatmap = np.zeros((frame_height, frame_width), dtype=np.float32)

while True:
    success, img = cap.read()
    if not success:
        break

    results = model(img, stream=True)

    for r in results:
        boxes = r.boxes
        for box in boxes:
            if box.conf[0] < 0.2:
                continue

            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            heatmap[y1:y2, x1:x2] += 1  

    heatmap_normalized = np.uint8(255 * heatmap / np.max(heatmap))
    heatmap_color = cv2.applyColorMap(heatmap_normalized, cv2.COLORMAP_JET)

    overlayed_image = cv2.addWeighted(img, 0.8, heatmap_color, 0.2, 0)

    cv2.imshow('Cumulative Heatmap Video', overlayed_image)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 25 persons, 1 handbag, 31.3ms
# Speed: 0.9ms preprocess, 31.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 30.9ms
# Speed: 2.0ms preprocess, 30.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 32.5ms
# Speed: 2.0ms preprocess, 32.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 27.7ms
# Speed: 1.9ms preprocess, 27.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 handbag, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 2 handbags, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 3 handbags, 26.6ms
# Speed: 2.5ms preprocess, 26.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
import cv2
import cvzone
import time
import math
import numpy as np

cap = cv2.VideoCapture(r"C:\Users\bathu\people_-_6387 (540p).mp4")

frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

model_path = "C:/Users/bathu/facial_recognition/yolov8l.pt"
model = YOLO(model_path)  

classNames = ['person']
heatmap = np.zeros((frame_height, frame_width), dtype=np.float32)

while True:
    success, img = cap.read()
    if not success:
        break

    results = model(img, stream=True)

    for r in results:
        boxes = r.boxes
        for box in boxes:
            if box.conf[0] < 0.2:
                continue

            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            heatmap[y1:y2, x1:x2] += 1  

heatmap_normalized = np.uint8(255 * heatmap / np.max(heatmap))
heatmap_color = cv2.applyColorMap(heatmap_normalized, cv2.COLORMAP_JET)

cv2.imshow('Cumulative Heatmap', heatmap_color)
cv2.waitKey(0)
cv2.destroyAllWindows()

cv2.imwrite('cumulative_heatmap.jpg', heatmap_color)

cap.release()
# Out:
# 0: 384x640 25 persons, 1 handbag, 30.4ms
# Speed: 3.0ms preprocess, 30.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 28.4ms
# Speed: 2.2ms preprocess, 28.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 28.0ms
# Speed: 2.8ms preprocess, 28.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 27.9ms
# Speed: 2.3ms preprocess, 27.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 handbag, 27.2ms
# Speed: 2.3ms preprocess, 27.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 2 handbags, 26.5ms
# Speed: 2.4ms preprocess, 26.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 3 handbags, 27.4ms
# Speed: 1.1ms preprocess, 27.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
import cv2
import cvzone
import time
import math
import numpy as np

cap = cv2.VideoCapture(r"C:\Users\bathu\people_-_6387 (540p).mp4")

frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

model_path = "C:/Users/bathu/facial_recognition/yolov8l.pt"
model = YOLO(model_path)  

classNames = ['person']
heatmap = np.zeros((frame_height, frame_width), dtype=np.float32)

fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('cumulative_heatmap.avi', fourcc, 20.0, (frame_width, frame_height))

while True:
    success, img = cap.read()
    if not success:
        break

    results = model(img, stream=True)

    for r in results:
        boxes = r.boxes
        for box in boxes:
            if box.conf[0] < 0.2:
                continue

            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            heatmap[y1:y2, x1:x2] += 1

    heatmap_normalized = np.uint8(255 * heatmap / np.max(heatmap))
    heatmap_color = cv2.applyColorMap(heatmap_normalized, cv2.COLORMAP_JET)

    overlayed_image = cv2.addWeighted(img, 0.8, heatmap_color, 0.2, 0)

    out.write(overlayed_image)

    cv2.imshow('Cumulative Heatmap Video', overlayed_image)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 25 persons, 1 handbag, 32.8ms
# Speed: 2.0ms preprocess, 32.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 32.3ms
# Speed: 2.5ms preprocess, 32.3ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 31.0ms
# Speed: 2.2ms preprocess, 31.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 26.9ms
# Speed: 1.1ms preprocess, 26.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 handbag, 26.9ms
# Speed: 2.1ms preprocess, 26.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 2 handbags, 30.9ms
# Speed: 4.0ms preprocess, 30.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 3 handbags, 26.9ms
# Speed: 2.0ms preprocess, 26.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
import cv2
import cvzone
import time
import math
import numpy as np

cap = cv2.VideoCapture(r"C:\Users\bathu\people_-_6387 (540p).mp4")

frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

model_path = "C:/Users/bathu/facial_recognition/yolov8l.pt"
model = YOLO(model_path)  # Replace with your YOLO model loading method

classNames = ['person']
heatmap = np.zeros((frame_height, frame_width), dtype=np.float32)

fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('cumulative_heatmap.avi', fourcc, 20.0, (frame_width, frame_height))

fixed_max_value = 100  

while True:
    success, img = cap.read()
    if not success:
        break

    results = model(img, stream=True)

    for r in results:
        boxes = r.boxes
        for box in boxes:
            if box.conf[0] < 0.2:
                continue

            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            heatmap[y1:y2, x1:x2] += 1  # Increment heatmap

    heatmap_normalized = np.uint8(255 * np.minimum(heatmap, fixed_max_value) / fixed_max_value)
    heatmap_color = cv2.applyColorMap(heatmap_normalized, cv2.COLORMAP_JET)

    overlayed_image = cv2.addWeighted(img, 0.8, heatmap_color, 0.2, 0)

    out.write(overlayed_image)

    cv2.imshow('Cumulative Heatmap Video', overlayed_image)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 25 persons, 1 handbag, 32.6ms
# Speed: 1.0ms preprocess, 32.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 31.0ms
# Speed: 2.0ms preprocess, 31.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 29.9ms
# Speed: 2.0ms preprocess, 29.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 27.0ms
# Speed: 2.7ms preprocess, 27.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 handbag, 28.2ms
# Speed: 1.3ms preprocess, 28.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 2 handbags, 36.4ms
# Speed: 1.0ms preprocess, 36.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 3 handbags, 26.7ms
# Speed: 1.1ms preprocess, 26.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
import cv2
import cvzone
import time
import math
import numpy as np

cap = cv2.VideoCapture(r"C:\Users\bathu\test4.mp4")

frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

model_path = "C:/Users/bathu/facial_recognition/yolov8l.pt"
model = YOLO(model_path)  

classNames = ['person']
heatmap = np.zeros((frame_height, frame_width), dtype=np.float32)

fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('cumulative_heatmap.avi', fourcc, 20.0, (frame_width, frame_height))

fixed_max_value = 100  

while True:
    success, img = cap.read()
    if not success:
        break

    results = model(img, stream=True)

    for r in results:
        boxes = r.boxes
        for box in boxes:
            if box.conf[0] < 0.2:
                continue

            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            heatmap[y1:y2, x1:x2] += 1  # Increment heatmap

    heatmap_normalized = np.uint8(255 * np.minimum(heatmap, fixed_max_value) / fixed_max_value)
    heatmap_color = cv2.applyColorMap(heatmap_normalized, cv2.COLORMAP_JET)

    overlayed_image = cv2.addWeighted(img, 0.8, heatmap_color, 0.2, 0)

    out.write(overlayed_image)

    cv2.imshow('Cumulative Heatmap Video', overlayed_image)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 15 persons, 1 umbrella, 1 handbag, 32.4ms
# Speed: 2.0ms preprocess, 32.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 umbrella, 1 handbag, 31.4ms
# Speed: 2.9ms preprocess, 31.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 umbrella, 1 handbag, 30.2ms
# Speed: 3.0ms preprocess, 30.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 25.9ms
# Speed: 1.5ms preprocess, 25.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 2 umbrellas, 26.9ms
# Speed: 1.0ms preprocess, 26.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 umbrella, 25.9ms
# Speed: 1.9ms preprocess, 25.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 25.9ms
# ...

# %%
import cv2
import cvzone
import time
import math
import numpy as np

cap = cv2.VideoCapture(r"C:\Users\bathu\people_-_6387 (540p).mp4")

frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

model_path = "C:/Users/bathu/facial_recognition/yolov8l.pt"
model = YOLO(model_path)  # Replace with your YOLO model loading method

classNames = ['person']
heatmap = np.zeros((frame_height, frame_width), dtype=np.float32)

out = cv2.VideoWriter('cumulative_heatmap.mp4', cv2.VideoWriter_fourcc(*'mp4v'), 20.0, (frame_width, frame_height))

fixed_max_value = 100  

while True:
    success, img = cap.read()
    if not success:
        break

    results = model(img, stream=True)

    for r in results:
        boxes = r.boxes
        for box in boxes:
            if box.conf[0] < 0.2:
                continue

            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            heatmap[y1:y2, x1:x2] += 1 

    heatmap_normalized = np.uint8(255 * np.minimum(heatmap, fixed_max_value) / fixed_max_value)
    heatmap_color = cv2.applyColorMap(heatmap_normalized, cv2.COLORMAP_JET)

    overlayed_image = cv2.addWeighted(img, 0.8, heatmap_color, 0.2, 0)

    out.write(overlayed_image)

    cv2.imshow('Cumulative_test4 Heatmap Video', overlayed_image)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 25 persons, 1 handbag, 31.9ms
# Speed: 3.0ms preprocess, 31.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 31.9ms
# Speed: 2.0ms preprocess, 31.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 27.9ms
# Speed: 2.0ms preprocess, 27.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 28.0ms
# Speed: 3.0ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 handbag, 27.5ms
# Speed: 1.1ms preprocess, 27.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 2 handbags, 26.4ms
# Speed: 2.0ms preprocess, 26.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 3 handbags, 26.9ms
# Speed: 2.0ms preprocess, 26.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
